# %%
# %pip install geopandas
# Out:
# ...
#   Using cached geopandas-1.1.1-py3-none-any.whl.metadata (2.3 kB)
# ...
# Using cached geopandas-1.1.1-py3-none-any.whl (338 kB)
# ...
#    ---------------------------------------- 0.0/19.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/19.2 MB ? eta -:--:--
#    - -------------------------------------- 0.5/19.2 MB 1.9 MB/s eta 0:00:10
#    -- ------------------------------------- 1.3/19.2 MB 2.7 MB/s eta 0:00:07
#    --- ------------------------------------ 1.8/19.2 MB 2.9 MB/s eta 0:00:07
#    ----- ---------------------------------- 2.9/19.2 MB 3.4 MB/s eta 0:00:05
#    -------- ------------------------------- 3.9/19.2 MB 3.7 MB/s eta 0:00:05
#    ---------- ----------------------------- 5.2/19.2 MB 4.1 MB/s eta 0:00:04
#    ----------- ---------------------------- 5.8/19.2 MB 3.9 MB/s eta 0:00:04
#    ------------- -------------------------- 6.3/19.2 MB 3.7 MB/s eta 0:00:04
#    ------------- -------------------------- 6.3/19.2 MB 3.7 MB/s eta 0:00:04
# ...

# %%
# Importing packages
import pyspark.sql.functions as F
import pandas as pd
import geopandas as gpd
import numpy as np

# %%
# Reading in the smartmeter time series data as a Spark DataFrame
sm_ts = spark.table("veiturdata_base_prd.ami.smartmeter")

# Displaying the first 10 rows of the dataframe
display(sm_ts.limit(10))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 # Reading in the smartmeter time series data as a Spark DataFrame
# ----> 2 sm_ts = spark.table("veiturdata_base_prd.ami.smartmeter")
#       4 # Displaying the first 10 rows of the dataframe
#       5 display(sm_ts.limit(10))
#
# NameError: name 'spark' is not defined
