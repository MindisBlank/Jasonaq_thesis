# %%
# Importing packages
import pyspark.sql.functions as F
import pandas as pd
import geopandas as gpd
import numpy as np

# %%
import pandas as pd

df_janitza = pd.read_parquet("../data/janitza_15min_all_20251101_1200_20251103_1200.parquet")
print(df_janitza.head())
print(df_janitza.columns)
print(df_janitza["dnr_str"].unique()[:1000])
# Out:
#                          ts           I_a           I_b         I_c  \
# 0 2025-11-01 12:00:00+00:00  35348.360497  39689.779703  497.617607
# 1 2025-11-01 12:15:00+00:00  34659.038805  41346.031775  496.769066
# 2 2025-11-01 12:30:00+00:00  33188.881083  40415.007259  500.968391
# 3 2025-11-01 12:45:00+00:00  33568.790325  40740.448124  479.575352
# 4 2025-11-01 13:00:00+00:00  33886.845846  39084.888952  481.942587
#
#         I_total dnr_str
# 0  75535.757807   D0006
# 1  76501.839645   D0006
# 2  74104.856733   D0006
# 3  74788.813801   D0006
# 4  73453.677385   D0006
# Index(['ts', 'I_a', 'I_b', 'I_c', 'I_total', 'dnr_str'], dtype='object')
# ['D0006' 'D0029' 'D0055' 'D0074' 'D0076' 'D0173' 'D0176' 'D0202' 'D0246'
#  'D0263' 'D0383' 'D0411' 'D0537' 'D0579' 'D0604' 'D0613' 'D0615' 'D0662'
#  'D0670' 'D0688' 'D0690' 'D0707' 'D0710' 'D0841' 'D1021' 'D1025' 'D1029'
#  'D1030' 'D1049' 'D1056' 'D1133' 'D1159' 'D1160' 'D1248' 'D1299' 'D1329'
# ...
